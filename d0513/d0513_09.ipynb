# %%
import oracledb
import pandas as pd
conn = oracledb.connect(user='ora_user',password='1111',dsn='localhost:1521/xe')

print(conn.version)
df = pd
# Out:
# 18.0.0.0.0

# %%
query = 'select employee_id,salary from employees'
df = pd.read_sql_query(query,conn)
x_list = list(df['EMPLOYEE_ID'].head())
x_list
df['SALARY'].head()
# Out:
# C:\Users\KOREAVC\AppData\Local\Temp\ipykernel_8416\3908825622.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query,conn)
# 0     7400.0
# 1     7300.0
# 2     6100.0
# 3    11000.0
# 4     8800.0
# Name: SALARY, dtype: float64

# %%
df['SALARY'].mean()
df[df['SALARY']>=df['SALARY'].mean()]
# Out:
#      EMPLOYEE_ID           EMP_NAME   SALARY
# 0            171      William Smith   7400.0
# 1            172    Elizabeth Bates   7300.0
# 3            174         Ellen Abel  11000.0
# 4            175      Alyssa Hutton   8800.0
# 5            176    Jonathon Taylor   8600.0
# 6            177    Jack Livingston   8400.0
# 7            178    Kimberely Grant   7000.0
# 30           201  Michael Hartstein  13000.0
# 32           203       Susan Mavris   6500.0
# 33           204       Hermann Baer  10000.0
# 34           205    Shelley Higgins  12008.0
# 35           206      William Gietz   8300.0
# 36           100        Steven King  24000.0
# 37           101      Neena Kochhar  17000.0
# 38           102        Lex De Haan  17000.0
# 39           103   Alexander Hunold   9000.0
# 44           108    Nancy Greenberg  12008.0
# 45           109      Daniel Faviet   9000.0
# 46           110          John Chen   8200.0
# 47           111     Ismael Sciarra   7700.0
# ...

# %%
import matplotlib.pyplot as plt
x = df.groupby('EMPLOYEE_ID')['SALARY'].sum().sort_values(ascending=True).index
y = df.groupby('EMPLOYEE_ID')['SALARY'].sum().sort_values(ascending=True).values

plt.bar(x,y)
# Out:
# <BarContainer object of 107 artists>
