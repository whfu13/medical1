# %%
import pandas as pd
df = pd.read_csv('../z20_data/stu_score1.csv',index_col='no')
df
# Out:
#             id  kor  eng  math  total        avg  rank      c_date
# no
# 1      Joelynn   55   87    68    210  70.000000     0  2024-04-04
# 2       Bambie   73   69    77    219  73.000000     0  2024-04-01
# 3         Orin   92   97    90    279  93.000000     0  2024-04-04
# 4         Puff   98   60    78    236  78.666667     0  2024-04-04
# 5      Godfree   66   72    59    197  65.666667     0  2024-04-06
# ...        ...  ...  ...   ...    ...        ...   ...         ...
# 996    Wilburt   59   64    51    174  58.000000     0  2024-04-01
# 997    Broddie   89   53    54    196  65.333333     0  2024-04-06
# 998     Baxter   63   82    78    223  74.333333     0  2024-04-02
# 999    Ignacio   61   60    96    217  72.333333     0  2024-04-07
# 1000  Wallache   83   64    56    203  67.666667     0  2024-04-08
#
# [1000 rows x 8 columns]

# %%
# total 220점 미만: 80, 이상이면 60으로 입력
# df['science'] = 60
flit = df['total']<220
df.loc[df[flit]>'science'] = 80
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       1 # total 220점 미만: 80, 이상이면 60으로 입력
#       2 # df['science'] = 60
#       3 flit = df['total']<220
# ----> 4 df.loc[df[flit]>'science'] = 80
#
# File c:\Python312\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Python312\Lib\site-packages\pandas\core\arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File c:\Python312\Lib\site-packages\pandas\core\frame.py:7900, in DataFrame._cmp_method(self, other, op)
#    7897 self, other = self._align_for_op(other, axis, flex=False, level=None)
#    7899 # See GH#4537 for discussion of scalar op behavior
# -> 7900 new_data = self._dispatch_frame_op(other, op, axis=axis)
#    7901 return self._construct_result(new_data)
#
# File c:\Python312\Lib\site-packages\pandas\core\frame.py:7945, in DataFrame._dispatch_frame_op(self, right, func, axis)
#    7942 right = lib.item_from_zerodim(right)
#    7943 if not is_list_like(right):
#    7944     # i.e. scalar, faster than checking np.ndim(right) == 0
# -> 7945     bm = self._mgr.apply(array_op, right=right)
#    7946     return self._constructor_from_mgr(bm, axes=bm.axes)
#    7948 elif isinstance(right, DataFrame):
#
# File c:\Python312\Lib\site-packages\pandas\core\internals\managers.py:361, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     358             kwargs[k] = obj[b.mgr_locs.indexer]
#     360 if callable(f):
# --> 361     applied = b.apply(f, **kwargs)
#     362 else:
#     363     applied = getattr(b, f)(**kwargs)
#
# File c:\Python312\Lib\site-packages\pandas\core\internals\blocks.py:393, in Block.apply(self, func, **kwargs)
#     387 @final
#     388 def apply(self, func, **kwargs) -> list[Block]:
#     389     """
#     390     apply the function to my values; return a block if we are not
#     391     one
#     392     """
# --> 393     result = func(self.values, **kwargs)
#     395     result = maybe_coerce_values(result)
#     396     return self._split_op_result(result)
#
# File c:\Python312\Lib\site-packages\pandas\core\ops\array_ops.py:341, in comparison_op(left, right, op)
#     337         res_values = np.zeros(lvalues.shape, dtype=bool)
#     339 elif is_numeric_v_string_like(lvalues, rvalues):
#     340     # GH#36377 going through the numexpr path would incorrectly raise
# --> 341     return invalid_comparison(lvalues, rvalues, op)
#     343 elif lvalues.dtype == object or isinstance(rvalues, str):
#     344     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#
# File c:\Python312\Lib\site-packages\pandas\core\ops\invalid.py:40, in invalid_comparison(left, right, op)
#      38 else:
#      39     typ = type(right).__name__
# ---> 40     raise TypeError(f"Invalid comparison between dtype={left.dtype} and {typ}")
#      41 return res_values
#
# TypeError: Invalid comparison between dtype=float64 and str

# %%
# total, avg 부분의 값을 변경

# %%
a_list = list(df.columns)
type(a_list)
# Out:
# list

# %%
a_list[0:4]
# Out:
# ['id', 'kor', 'eng', 'math']

# %%
## list슬라이싱은 그대로, 1개의 슬라이싱 리스트로 변경해서, 각각의 list를 합침
df = df[a_list[0:4]+[a_list[-1]]+a_list[4:-1]]

# %%
df
# Out:
#             id  kor  eng  math  science  total        avg  rank      c_date
# no
# 1      Joelynn   55   87    68       60    210  70.000000     0  2024-04-04
# 2       Bambie   73   69    77       60    219  73.000000     0  2024-04-01
# 3         Orin   92   97    90       60    279  93.000000     0  2024-04-04
# 4         Puff   98   60    78       60    236  78.666667     0  2024-04-04
# 5      Godfree   66   72    59       60    197  65.666667     0  2024-04-06
# ...        ...  ...  ...   ...      ...    ...        ...   ...         ...
# 996    Wilburt   59   64    51       60    174  58.000000     0  2024-04-01
# 997    Broddie   89   53    54       60    196  65.333333     0  2024-04-06
# 998     Baxter   63   82    78       60    223  74.333333     0  2024-04-02
# 999    Ignacio   61   60    96       60    217  72.333333     0  2024-04-07
# 1000  Wallache   83   64    56       60    203  67.666667     0  2024-04-08
#
# [1000 rows x 9 columns]
