# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # 한글설정
matplotlib.rcParams['font.size'] = 10 # 글자크기
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
import pandas as pd
df = pd.read_excel('../z20_data/20230104_연령별인구현황2.xlsx',skiprows=3,thousands=',',index_col='행정기관',usecols='B,E:Y')
df.head()
# Out:
#            0~4세     5~9세   10~14세   15~19세   20~24세   25~29세   30~34세  \
# 행정기관
# 전국       726460  1072653  1211077  1211949  1524378  1823908  1737714
# 서울특별시    116614   161429   185689   197425   271237   390716   379852
# 부산광역시     41333    63912    68919    67836    93245   109745   103536
# 대구광역시     31269    49000    55029    57661    74228    81001    76198
# 인천광역시     43664    63028    70593    69580    86548   108831   107658
#
#           35~39세   40~44세   45~49세  ...   55~59세   60~64세   65~69세   70~74세  \
# 행정기관                                ...
# 전국       1684266  2055130  2039606  ...  2052227  2097254  1554976  1038388
# 서울특별시     332153   363795   352011  ...   338380   343434   271757   188172
# 부산광역시      99530   127544   121660  ...   126702   143246   119500    83807
# 대구광역시      71455    87860    91327  ...    96673    96632    71324    49675
# 인천광역시     102829   126090   121064  ...   121717   124470    84563    52236
#
# ...

# %%
# for i in range(df.shape[1]):
#     df[df.columns[i]] = df[df.columns[i]].str.replace(",","").astype(int)

# %%
df.columns
# Out:
# Index(['0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세',
#        '35~39세', '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세',
#        '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상'],
#       dtype='object')

# %%
x = ['2023년 1월']
y1 = df.iloc[0,:3].sum() # df['0~14세'] 
y2 = df.iloc[0,3:13].sum() # df['15~64세']
y3 = df.iloc[0,13:].sum() # df['65세이상']
plt.bar(x,y1,bottom=y2+y3,label='0~14세',color='#47c3f5')
plt.bar(x,y2,bottom=y3,label='15~64세',color='#34393b')
plt.bar(x,y3,label='65세 이상',color='#42f56c')
x1= ['2023년 2월']
y4 = df.iloc[0,:3].sum() # df['0~14세'] 
y5 = df.iloc[0,3:13].sum() # df['15~64세']
y6 = df.iloc[0,13:].sum() # df['65세이상']
plt.bar(x1,y4,bottom=y5+y6,color='#47c3f5')
plt.bar(x1,y5,bottom=y6,color='#34393b')
plt.bar(x1,y6,color='#42f56c')
x2= ['2023년 3월']
y7 = df.iloc[0,:3].sum() # df['0~14세'] 
y8 = df.iloc[0,3:13].sum() # df['15~64세']
y9 = df.iloc[0,13:].sum() # df['65세이상']
plt.bar(x2,y7,bottom=y8+y9,color='#47c3f5')
plt.bar(x2,y8,bottom=y9,color='#34393b')
plt.bar(x2,y9,color='#42f56c')
x3= ['2023년 4월']
y10 = df.iloc[0,:3].sum() # df['0~14세'] 
y11 = df.iloc[0,3:13].sum() # df['15~64세']
y12 = df.iloc[0,13:].sum() # df['65세이상']
plt.bar(x3,y10,bottom=y11+y12,color='#47c3f5')
plt.bar(x3,y11,bottom=y12,color='#34393b')
plt.bar(x3,y12,color='#42f56c')

# plt.figure(figsize=(15,5))

# 값 표시
# for i,txt in enumerate(y1):
#     plt.text(x[i],y1[i]-12,txt,ha='center')
# for i,txt in enumerate(y2):
#     plt.text(x[i],y1[i]+y2[i],txt,ha='center')
# for i,txt in enumerate(y3):
#     plt.text(x[i],y1[i]+y2[i]+y3[i],txt,ha='center')
# plt.ylim([0,600000])
plt.title('전국')
plt.legend(loc='lower center',ncols=3)
# plt.yticks([x for x in range(100000)])
plt.show()
