# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # 한글설정
matplotlib.rcParams['font.size'] = 10 # 글자크기
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
import pandas as pd
df_m= pd.read_excel('../z20_data/20230104_연령별인구현황2.xlsx',skiprows=3,index_col='행정기관',usecols='B,E:Y')
df_m.head(1)
# Out:
#          0~4세       5~9세     10~14세     15~19세     20~24세     25~29세  \
# 행정기관
# 전국    726,460  1,072,653  1,211,077  1,211,949  1,524,378  1,823,908
#
#          30~34세     35~39세     40~44세     45~49세  ...     55~59세     60~64세  \
# 행정기관                                              ...
# 전국    1,737,714  1,684,266  2,055,130  2,039,606  ...  2,052,227  2,097,254
#
#          65~69세     70~74세   75~79세   80~84세   85~89세  90~94세 95~99세 100세 이상
# 행정기관
# 전국    1,554,976  1,038,388  713,448  507,915  212,726  54,180  8,880   1,307
#
# [1 rows x 21 columns]

# %%
import pandas as pd
df_w= pd.read_excel('../z20_data/20230104_연령별인구현황2.xlsx',skiprows=3,index_col='행정기관',usecols='B,AB:AV')
df_w.head(1)
# Out:
#        0~4세.1     5~9세.1   10~14세.1   15~19세.1   20~24세.1   25~29세.1  \
# 행정기관
# 전국    691,045  1,020,598  1,144,645  1,134,811  1,402,493  1,642,682
#
#        30~34세.1   35~39세.1   40~44세.1   45~49세.1  ...   55~59세.1   60~64세.1  \
# 행정기관                                              ...
# 전국    1,579,871  1,598,401  1,980,502  1,990,483  ...  2,017,243  2,132,394
#
#        65~69세.1   70~74세.1 75~79세.1 80~84세.1 85~89세.1 90~94세.1 95~99세.1  \
# 행정기관
# 전국    1,649,709  1,174,486  908,877  802,501  459,932  177,039   39,806
#
#      100세 이상.1
# 행정기관
# 전국       6,604
#
# [1 rows x 21 columns]

# %%
# 2023년 1월 남자 데이터 소수점 제거
for i in range(df_m.shape[1]):
    df_m[df_m.columns[i]] = df_m[df_m.columns[i]].str.replace(",","").astype(int)

# %%
# 2023년 1월 여자 데이터 소수점 제거
for i in range(df_w.shape[1]):
    df_w[df_w.columns[i]] = df_w[df_w.columns[i]].str.replace(",","").astype(int)

# %% [markdown]
# ##### 연령별 인구현황
# - 2023년 1월 연령별 인구수를 가로 막대그래프로 출력하시오.

# %%
print(df_m.columns)
print(df_w.columns)
# Out:
# Index(['0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세',
#        '35~39세', '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세',
#        '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상'],
#       dtype='object')
# Index(['0~4세.1', '5~9세.1', '10~14세.1', '15~19세.1', '20~24세.1', '25~29세.1',
#        '30~34세.1', '35~39세.1', '40~44세.1', '45~49세.1', '50~54세.1', '55~59세.1',
#        '60~64세.1', '65~69세.1', '70~74세.1', '75~79세.1', '80~84세.1', '85~89세.1',
#        '90~94세.1', '95~99세.1', '100세 이상.1'],
#       dtype='object')

# %%
# 남자데이터, 여자데이터 컬럼명 통일
df_w.columns = df_m.columns
print(df_w.columns)
# Out:
# Index(['0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세',
#        '35~39세', '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세',
#        '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상'],
#       dtype='object')

# %%
df_total = df_m

# %%
# 2023년 1월
plt.figure(figsize=(10,7))
plt.barh(df_m.columns,-df_m.iloc[0]//1000,label='남자인구')
plt.barh(df_w.columns,df_w.iloc[0]//1000,label='여자인구')
plt.title('2023년 1월 대한민국 인구 피라미드')
plt.legend(loc=1)
plt.show()

# %% [markdown]
# ##### 1월,2월,3월,4월 합산을 해서 가로막대그래프를 출력하시오.

# %%
import pandas as pd
df_m1= pd.read_excel('../z20_data/20230104_연령별인구현황2.xlsx',skiprows=3,index_col='행정기관',usecols='B,AY:BS')
df_m1.head(1)
# Out:
#        0~4세.2     5~9세.2   10~14세.2   15~19세.2   20~24세.2   25~29세.2  \
# 행정기관
# 전국    722,848  1,067,962  1,210,328  1,210,202  1,516,184  1,816,653
#
#        30~34세.2   35~39세.2   40~44세.2   45~49세.2  ...   55~59세.2   60~64세.2  \
# 행정기관                                              ...
# 전국    1,738,039  1,676,299  2,058,847  2,038,344  ...  2,054,837  2,102,187
#
#        65~69세.2   70~74세.2 75~79세.2 80~84세.2 85~89세.2 90~94세.2 95~99세.2  \
# 행정기관
# 전국    1,563,546  1,039,913  714,082  513,601  214,782   54,804    9,005
#
#      100세 이상.2
# 행정기관
# 전국       1,391
#
# [1 rows x 21 columns]

# %%
# 2023년 2월 남자 데이터 소수점 제거
for i in range(df_m1.shape[1]):
    df_m1[df_m1.columns[i]] = df_m1[df_m1.columns[i]].str.replace(",","").astype(int)

# %%
import pandas as pd
df_w1= pd.read_excel('../z20_data/20230104_연령별인구현황2.xlsx',skiprows=3,index_col='행정기관',usecols='B,BV:CP')
df_w1.head(1)
# Out:
#        0~4세.3     5~9세.3   10~14세.3   15~19세.3   20~24세.3   25~29세.3  \
# 행정기관
# 전국    687,427  1,016,418  1,143,877  1,133,259  1,395,777  1,637,682
#
#        30~34세.3   35~39세.3   40~44세.3   45~49세.3  ...   55~59세.3   60~64세.3  \
# 행정기관                                              ...
# 전국    1,579,098  1,588,368  1,984,303  1,987,300  ...  2,021,614  2,137,849
#
#        65~69세.3   70~74세.3 75~79세.3 80~84세.3 85~89세.3 90~94세.3 95~99세.3  \
# 행정기관
# 전국    1,657,545  1,176,527  909,717  805,628  463,285  178,743   40,538
#
#      100세 이상.3
# 행정기관
# 전국       6,772
#
# [1 rows x 21 columns]

# %%
# 2023년 2월 여자 데이터 소수점 제거
for i in range(df_w1.shape[1]):
    df_w1[df_w1.columns[i]] = df_w1[df_w1.columns[i]].str.replace(",","").astype(int)

# %%
df_w1.columns = df_m1.columns
print(df_w1.columns)
# Out:
# Index(['0~4세.2', '5~9세.2', '10~14세.2', '15~19세.2', '20~24세.2', '25~29세.2',
#        '30~34세.2', '35~39세.2', '40~44세.2', '45~49세.2', '50~54세.2', '55~59세.2',
#        '60~64세.2', '65~69세.2', '70~74세.2', '75~79세.2', '80~84세.2', '85~89세.2',
#        '90~94세.2', '95~99세.2', '100세 이상.2'],
#       dtype='object')

# %%
# 타입 변경 2023년 1월데이터 + 2월데이터
for i in range(df_m.shape[1]):
    pass
    # df_total[df.columns[i]] = df[df.columns[i]]+df2[df.columns[i]]+df3[df.columns[i]]+df4[df.columns[i]]
    
# df_total

# %%
import pandas as pd
df_m2= pd.read_excel('../z20_data/20230104_연령별인구현황2.xlsx',skiprows=3,index_col='행정기관',usecols='B,CS:DM')
df_m2.head(1)
# Out:
#        0~4세.4     5~9세.4   10~14세.4   15~19세.4   20~24세.4   25~29세.4  \
# 행정기관
# 전국    718,749  1,063,773  1,208,169  1,208,266  1,508,626  1,814,509
#
#        30~34세.4   35~39세.4   40~44세.4   45~49세.4  ...   55~59세.4   60~64세.4  \
# 행정기관                                              ...
# 전국    1,748,021  1,669,407  2,057,937  2,028,959  ...  2,058,136  2,105,716
#
#        65~69세.4   70~74세.4 75~79세.4 80~84세.4 85~89세.4 90~94세.4 95~99세.4  \
# 행정기관
# 전국    1,572,761  1,043,543  718,702  515,358  217,307   55,442    9,119
#
#      100세 이상.4
# 행정기관
# 전국       1,429
#
# [1 rows x 21 columns]

# %%
import pandas as pd
df_w2= pd.read_excel('../z20_data/20230104_연령별인구현황2.xlsx',skiprows=3,index_col='행정기관',usecols='B,DP:EJ')
df_w2.head(1)
# Out:
#        0~4세.5     5~9세.5   10~14세.5   15~19세.5   20~24세.5   25~29세.5  \
# 행정기관
# 전국    683,499  1,012,269  1,142,345  1,131,608  1,389,208  1,637,011
#
#        30~34세.5   35~39세.5   40~44세.5   45~49세.5  ...   55~59세.5   60~64세.5  \
# 행정기관                                              ...
# 전국    1,586,436  1,581,605  1,983,095  1,977,469  ...  2,026,849  2,140,345
#
#        65~69세.5   70~74세.5 75~79세.5 80~84세.5 85~89세.5 90~94세.5 95~99세.5  \
# 행정기관
# 전국    1,666,718  1,181,147  912,158  807,453  467,750  180,147   41,089
#
#      100세 이상.5
# 행정기관
# 전국       6,932
#
# [1 rows x 21 columns]

# %%
plt.barh(df_m.columns,df_m.iloc[0])
plt.barh(df_m1.columns,df_m1.iloc[0])
# Out:
# <BarContainer object of 21 artists>
